# %% [markdown]
# ## Semester 1 Project Submission
#
# Please fill out:
# * Student name: Jacky Rivera
# * Instructor name: JP Ventura & Julian Ward

# %%
# Your code here - remember to use markdown cells for comments as well!

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sqlite3
import numpy as np
import zipfile
import sqlite3
import pandas as pd
# %matplotlib inline

# %%
movie3 = pd.read_csv("zippedData/bom.movie_gross.csv.gz")
movie3 = movie3.rename(columns={'title':"movie"})
movie3['movie'] = movie3['movie'].map(lambda x: "Harry Potter and the Deathly Hallows: Part 1" if x == "Harry Potter and the Deathly Hallows Part 1" else x)
movie3.head()
# Out:
#                                           movie studio  domestic_gross  \
# 0                                   Toy Story 3     BV     415000000.0
# 1                    Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows: Part 1     WB     296000000.0
# 3                                     Inception     WB     292600000.0
# 4                           Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
#pulling in movie budgets dataset and preparing it for joining by changing object types to int.

# %%
moviebudgets = pd.read_csv("zippedData/tn.movie_budgets.csv.gz")
moviebudgets["production_budget"] = moviebudgets['production_budget'].map(lambda x: x.strip("$"))
moviebudgets["production_budget"] = moviebudgets['production_budget'].map(lambda x: x.replace(",", ""))

moviebudgets["domestic_gross"] = moviebudgets['domestic_gross'].map(lambda x: x.strip("$"))
moviebudgets["domestic_gross"] = moviebudgets['domestic_gross'].map(lambda x: x.replace(",",""))

moviebudgets["worldwide_gross"] = moviebudgets['worldwide_gross'].map(lambda x: x.strip("$"))
moviebudgets["worldwide_gross"] = moviebudgets['worldwide_gross'].map(lambda x: x.replace(",",""))


moviebudgets= moviebudgets.astype({'production_budget': np.int64, 'domestic_gross': np.int64, 'worldwide_gross': np.int64})
moviebudgets.head(10)
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# 5   6  Dec 18, 2015         Star Wars Ep. VII: The Force Awakens
# 6   7  Apr 27, 2018                       Avengers: Infinity War
# 7   8  May 24, 2007   Pirates of the Caribbean: At Worldâs End
# 8   9  Nov 17, 2017                               Justice League
# 9  10   Nov 6, 2015                                      Spectre
#
#    production_budget  domestic_gross  worldwide_gross
# 0          425000000       760507625       2776345279
# 1          410600000       241063875       1045663875
# 2          350000000        42762350        149762350
# 3          330600000       459005868       1403013963
# 4          317000000       620181382       1316721747
# 5          306000000       936662225       2053311220
# 6          300000000       678815482       2048134200
# 7          300000000       309420425        963420425
# 8          300000000       229024295        655945209
# 9          300000000       200074175        879620923

# %%
#joining movie budgets dataset with bom movie gross so we can have the studio names

# %%
movie_total_gross = movie3.join(moviebudgets.set_index("movie"), on= ['movie'],rsuffix = "___")
movie_total_gross = movie_total_gross.set_index('id')
movie_total_gross
# Out:
#                                              movie      studio  \
# id
# 47.0                                   Toy Story 3          BV
# NaN                     Alice in Wonderland (2010)          BV
# NaN   Harry Potter and the Deathly Hallows: Part 1          WB
# 38.0                                     Inception          WB
# 27.0                           Shrek Forever After        P/DW
# ...                                            ...         ...
# NaN                                      The Quake       Magn.
# NaN                    Edward II (2018 re-release)          FM
# NaN                                       El Pacto        Sony
# NaN                                       The Swan  Synergetic
# NaN                              An Actor Prepares       Grav.
#
#       domestic_gross foreign_gross  year  release_date  production_budget  \
# id
# 47.0     415000000.0     652000000  2010  Jun 18, 2010        200000000.0
# NaN      334200000.0     691300000  2010           NaN                NaN
# NaN      296000000.0     664300000  2010           NaN                NaN
# 38.0     292600000.0     535700000  2010  Jul 16, 2010        160000000.0
# 27.0     238700000.0     513900000  2010  May 21, 2010        165000000.0
# ...              ...           ...   ...           ...                ...
# NaN           6200.0           NaN  2018           NaN                NaN
# NaN           4800.0           NaN  2018           NaN                NaN
# NaN           2500.0           NaN  2018           NaN                NaN
# NaN           2400.0           NaN  2018           NaN                NaN
# NaN           1700.0           NaN  2018           NaN                NaN
#
#       domestic_gross___  worldwide_gross
# id
# 47.0        415004880.0     1.068880e+09
# NaN                 NaN              NaN
# NaN                 NaN              NaN
# 38.0        292576195.0     8.355246e+08
# 27.0        238736787.0     7.562447e+08
# ...                 ...              ...
# NaN                 NaN              NaN
# NaN                 NaN              NaN
# NaN                 NaN              NaN
# NaN                 NaN              NaN
# NaN                 NaN              NaN
#
# [3396 rows x 9 columns]

# %%
movie4 = pd.read_csv('zippedData/tmdb.movies.csv.gz')

# %%
movie4= movie4.rename(columns={'original_title':"movie"})
movie4 = movie4.set_index("movie")

# %%
#pullin in tmdb ratings so we have budget info and ratings

# %%
movies_and_rating = movie_total_gross.join(movie4, on = 'movie', how = 'outer', lsuffix = '__')

# %%
movies_and_rating
# Out:
#                                              movie studio  domestic_gross  \
# 47.0                                   Toy Story 3     BV     415000000.0
# NaN                     Alice in Wonderland (2010)     BV     334200000.0
# NaN   Harry Potter and the Deathly Hallows: Part 1     WB     296000000.0
# 38.0                                     Inception     WB     292600000.0
# 27.0                           Shrek Forever After   P/DW     238700000.0
# ...                                            ...    ...             ...
# NaN                          Laboratory Conditions    NaN             NaN
# NaN                                _EXHIBIT_84xxx_    NaN             NaN
# NaN                                   The Last One    NaN             NaN
# NaN                                   Trailer Made    NaN             NaN
# NaN                                     The Church    NaN             NaN
#
#      foreign_gross    year release_date__  production_budget  \
# 47.0     652000000  2010.0   Jun 18, 2010        200000000.0
# NaN      691300000  2010.0            NaN                NaN
# NaN      664300000  2010.0            NaN                NaN
# 38.0     535700000  2010.0   Jul 16, 2010        160000000.0
# 27.0     513900000  2010.0   May 21, 2010        165000000.0
# ...            ...     ...            ...                ...
# NaN            NaN     NaN            NaN                NaN
# NaN            NaN     NaN            NaN                NaN
# NaN            NaN     NaN            NaN                NaN
# NaN            NaN     NaN            NaN                NaN
# NaN            NaN     NaN            NaN                NaN
#
#       domestic_gross___  worldwide_gross  Unnamed: 0                genre_ids  \
# 47.0        415004880.0     1.068880e+09         7.0          [16, 10751, 35]
# NaN                 NaN              NaN         NaN                      NaN
# NaN                 NaN              NaN         0.0          [12, 14, 10751]
# 38.0        292576195.0     8.355246e+08         4.0            [28, 878, 12]
# 27.0        238736787.0     7.562447e+08        38.0  [35, 12, 14, 16, 10751]
# ...                 ...              ...         ...                      ...
# NaN                 NaN              NaN     26512.0                 [27, 18]
# NaN                 NaN              NaN     26513.0                 [18, 53]
# NaN                 NaN              NaN     26514.0             [14, 28, 12]
# NaN                 NaN              NaN     26515.0          [10751, 12, 28]
# NaN                 NaN              NaN     26516.0                 [53, 27]
#
#             id original_language  popularity release_date  \
# 47.0   10193.0                en      24.445   2010-06-17
# NaN        NaN               NaN         NaN          NaN
# NaN    12444.0                en      33.533   2010-11-19
# 38.0   27205.0                en      27.920   2010-07-16
# 27.0   10192.0                en      15.041   2010-05-16
# ...        ...               ...         ...          ...
# NaN   488143.0                en       0.600   2018-10-13
# NaN   485975.0                en       0.600   2018-05-01
# NaN   381231.0                en       0.600   2018-10-01
# NaN   366854.0                en       0.600   2018-06-22
# NaN   309885.0                en       0.600   2018-10-05
#
#                                              title  vote_average  vote_count
# 47.0                                   Toy Story 3           7.7      8340.0
# NaN                                            NaN           NaN         NaN
# NaN   Harry Potter and the Deathly Hallows: Part 1           7.7     10788.0
# 38.0                                     Inception           8.3     22186.0
# 27.0                           Shrek Forever After           6.1      3843.0
# ...                                            ...           ...         ...
# NaN                          Laboratory Conditions           0.0         1.0
# NaN                                _EXHIBIT_84xxx_           0.0         1.0
# NaN                                   The Last One           0.0         1.0
# NaN                                   Trailer Made           0.0         1.0
# NaN                                     The Church           0.0         1.0
#
# [27975 rows x 18 columns]

# %%
movies_and_rating.head()
# Out:
#                                              movie studio  domestic_gross  \
# 47.0                                   Toy Story 3     BV     415000000.0
# NaN                     Alice in Wonderland (2010)     BV     334200000.0
# NaN   Harry Potter and the Deathly Hallows: Part 1     WB     296000000.0
# 38.0                                     Inception     WB     292600000.0
# 27.0                           Shrek Forever After   P/DW     238700000.0
#
#      foreign_gross    year release_date__  production_budget  \
# 47.0     652000000  2010.0   Jun 18, 2010        200000000.0
# NaN      691300000  2010.0            NaN                NaN
# NaN      664300000  2010.0            NaN                NaN
# 38.0     535700000  2010.0   Jul 16, 2010        160000000.0
# 27.0     513900000  2010.0   May 21, 2010        165000000.0
#
#       domestic_gross___  worldwide_gross  Unnamed: 0                genre_ids  \
# 47.0        415004880.0     1.068880e+09         7.0          [16, 10751, 35]
# NaN                 NaN              NaN         NaN                      NaN
# NaN                 NaN              NaN         0.0          [12, 14, 10751]
# 38.0        292576195.0     8.355246e+08         4.0            [28, 878, 12]
# 27.0        238736787.0     7.562447e+08        38.0  [35, 12, 14, 16, 10751]
#
#            id original_language  popularity release_date  \
# 47.0  10193.0                en      24.445   2010-06-17
# NaN       NaN               NaN         NaN          NaN
# NaN   12444.0                en      33.533   2010-11-19
# 38.0  27205.0                en      27.920   2010-07-16
# 27.0  10192.0                en      15.041   2010-05-16
#
#                                              title  vote_average  vote_count
# 47.0                                   Toy Story 3           7.7      8340.0
# NaN                                            NaN           NaN         NaN
# NaN   Harry Potter and the Deathly Hallows: Part 1           7.7     10788.0
# 38.0                                     Inception           8.3     22186.0
# 27.0                           Shrek Forever After           6.1      3843.0

# %%
#dropping unnecessary columns

# %%
movies_and_rating.drop(["Unnamed: 0",'id','title', 'genre_ids', 'title'],  axis=1, inplace=True)

# %%
movies_and_rating = movies_and_rating.set_index('movie')

# %%
movies_and_rating
# Out:
#                                              studio  domestic_gross  \
# movie
# Toy Story 3                                      BV     415000000.0
# Alice in Wonderland (2010)                       BV     334200000.0
# Harry Potter and the Deathly Hallows: Part 1     WB     296000000.0
# Inception                                        WB     292600000.0
# Shrek Forever After                            P/DW     238700000.0
# ...                                             ...             ...
# Laboratory Conditions                           NaN             NaN
# _EXHIBIT_84xxx_                                 NaN             NaN
# The Last One                                    NaN             NaN
# Trailer Made                                    NaN             NaN
# The Church                                      NaN             NaN
#
#                                              foreign_gross    year  \
# movie
# Toy Story 3                                      652000000  2010.0
# Alice in Wonderland (2010)                       691300000  2010.0
# Harry Potter and the Deathly Hallows: Part 1     664300000  2010.0
# Inception                                        535700000  2010.0
# Shrek Forever After                              513900000  2010.0
# ...                                                    ...     ...
# Laboratory Conditions                                  NaN     NaN
# _EXHIBIT_84xxx_                                        NaN     NaN
# The Last One                                           NaN     NaN
# Trailer Made                                           NaN     NaN
# The Church                                             NaN     NaN
#
#                                              release_date__  \
# movie
# Toy Story 3                                    Jun 18, 2010
# Alice in Wonderland (2010)                              NaN
# Harry Potter and the Deathly Hallows: Part 1            NaN
# Inception                                      Jul 16, 2010
# Shrek Forever After                            May 21, 2010
# ...                                                     ...
# Laboratory Conditions                                   NaN
# _EXHIBIT_84xxx_                                         NaN
# The Last One                                            NaN
# Trailer Made                                            NaN
# The Church                                              NaN
#
#                                               production_budget  \
# movie
# Toy Story 3                                         200000000.0
# Alice in Wonderland (2010)                                  NaN
# Harry Potter and the Deathly Hallows: Part 1                NaN
# Inception                                           160000000.0
# Shrek Forever After                                 165000000.0
# ...                                                         ...
# Laboratory Conditions                                       NaN
# _EXHIBIT_84xxx_                                             NaN
# The Last One                                                NaN
# Trailer Made                                                NaN
# The Church                                                  NaN
#
#                                               domestic_gross___  \
# movie
# Toy Story 3                                         415004880.0
# Alice in Wonderland (2010)                                  NaN
# Harry Potter and the Deathly Hallows: Part 1                NaN
# Inception                                           292576195.0
# Shrek Forever After                                 238736787.0
# ...                                                         ...
# Laboratory Conditions                                       NaN
# _EXHIBIT_84xxx_                                             NaN
# The Last One                                                NaN
# Trailer Made                                                NaN
# The Church                                                  NaN
#
#                                               worldwide_gross  \
# movie
# Toy Story 3                                      1.068880e+09
# Alice in Wonderland (2010)                                NaN
# Harry Potter and the Deathly Hallows: Part 1              NaN
# Inception                                        8.355246e+08
# Shrek Forever After                              7.562447e+08
# ...                                                       ...
# Laboratory Conditions                                     NaN
# _EXHIBIT_84xxx_                                           NaN
# The Last One                                              NaN
# Trailer Made                                              NaN
# The Church                                                NaN
#
#                                              original_language  popularity  \
# movie
# Toy Story 3                                                 en      24.445
# Alice in Wonderland (2010)                                 NaN         NaN
# Harry Potter and the Deathly Hallows: Part 1                en      33.533
# Inception                                                   en      27.920
# Shrek Forever After                                         en      15.041
# ...                                                        ...         ...
# Laboratory Conditions                                       en       0.600
# _EXHIBIT_84xxx_                                             en       0.600
# The Last One                                                en       0.600
# Trailer Made                                                en       0.600
# The Church                                                  en       0.600
#
#                                              release_date  vote_average  \
# movie
# Toy Story 3                                    2010-06-17           7.7
# Alice in Wonderland (2010)                            NaN           NaN
# Harry Potter and the Deathly Hallows: Part 1   2010-11-19           7.7
# Inception                                      2010-07-16           8.3
# Shrek Forever After                            2010-05-16           6.1
# ...                                                   ...           ...
# Laboratory Conditions                          2018-10-13           0.0
# _EXHIBIT_84xxx_                                2018-05-01           0.0
# The Last One                                   2018-10-01           0.0
# Trailer Made                                   2018-06-22           0.0
# The Church                                     2018-10-05           0.0
#
#                                               vote_count
# movie
# Toy Story 3                                       8340.0
# Alice in Wonderland (2010)                           NaN
# Harry Potter and the Deathly Hallows: Part 1     10788.0
# Inception                                        22186.0
# Shrek Forever After                               3843.0
# ...                                                  ...
# Laboratory Conditions                                1.0
# _EXHIBIT_84xxx_                                      1.0
# The Last One                                         1.0
# Trailer Made                                         1.0
# The Church                                           1.0
#
# [27975 rows x 13 columns]

# %%
#dropping movies that don't have enough information to be of use

# %%
movies_and_rating.dropna(axis = 0, thresh = 6, inplace = True)

# %%
movies_and_rating
# Out:
#                                               studio  domestic_gross  \
# movie
# Toy Story 3                                       BV     415000000.0
# Harry Potter and the Deathly Hallows: Part 1      WB     296000000.0
# Inception                                         WB     292600000.0
# Shrek Forever After                             P/DW     238700000.0
# The Twilight Saga: Eclipse                      Sum.     300500000.0
# ...                                              ...             ...
# Loving Pablo                                    Uni.         22000.0
# The Escape                                       IFC         14000.0
# The Escape                                       IFC         14000.0
# Souvenir                                      Strand         11400.0
# An Actor Prepares                              Grav.          1700.0
#
#                                              foreign_gross    year  \
# movie
# Toy Story 3                                      652000000  2010.0
# Harry Potter and the Deathly Hallows: Part 1     664300000  2010.0
# Inception                                        535700000  2010.0
# Shrek Forever After                              513900000  2010.0
# The Twilight Saga: Eclipse                       398000000  2010.0
# ...                                                    ...     ...
# Loving Pablo                                           NaN  2018.0
# The Escape                                             NaN  2018.0
# The Escape                                             NaN  2018.0
# Souvenir                                               NaN  2018.0
# An Actor Prepares                                      NaN  2018.0
#
#                                              release_date__  \
# movie
# Toy Story 3                                    Jun 18, 2010
# Harry Potter and the Deathly Hallows: Part 1            NaN
# Inception                                      Jul 16, 2010
# Shrek Forever After                            May 21, 2010
# The Twilight Saga: Eclipse                     Jun 30, 2010
# ...                                                     ...
# Loving Pablo                                            NaN
# The Escape                                              NaN
# The Escape                                              NaN
# Souvenir                                                NaN
# An Actor Prepares                                       NaN
#
#                                               production_budget  \
# movie
# Toy Story 3                                         200000000.0
# Harry Potter and the Deathly Hallows: Part 1                NaN
# Inception                                           160000000.0
# Shrek Forever After                                 165000000.0
# The Twilight Saga: Eclipse                           68000000.0
# ...                                                         ...
# Loving Pablo                                                NaN
# The Escape                                                  NaN
# The Escape                                                  NaN
# Souvenir                                                    NaN
# An Actor Prepares                                           NaN
#
#                                               domestic_gross___  \
# movie
# Toy Story 3                                         415004880.0
# Harry Potter and the Deathly Hallows: Part 1                NaN
# Inception                                           292576195.0
# Shrek Forever After                                 238736787.0
# The Twilight Saga: Eclipse                          300531751.0
# ...                                                         ...
# Loving Pablo                                                NaN
# The Escape                                                  NaN
# The Escape                                                  NaN
# Souvenir                                                    NaN
# An Actor Prepares                                           NaN
#
#                                               worldwide_gross  \
# movie
# Toy Story 3                                      1.068880e+09
# Harry Potter and the Deathly Hallows: Part 1              NaN
# Inception                                        8.355246e+08
# Shrek Forever After                              7.562447e+08
# The Twilight Saga: Eclipse                       7.061028e+08
# ...                                                       ...
# Loving Pablo                                              NaN
# The Escape                                                NaN
# The Escape                                                NaN
# Souvenir                                                  NaN
# An Actor Prepares                                         NaN
#
#                                              original_language  popularity  \
# movie
# Toy Story 3                                                 en      24.445
# Harry Potter and the Deathly Hallows: Part 1                en      33.533
# Inception                                                   en      27.920
# Shrek Forever After                                         en      15.041
# The Twilight Saga: Eclipse                                  en      20.340
# ...                                                        ...         ...
# Loving Pablo                                                es      12.937
# The Escape                                                  en       0.600
# The Escape                                                  en       1.176
# Souvenir                                                    fr       2.130
# An Actor Prepares                                           en       7.244
#
#                                              release_date  vote_average  \
# movie
# Toy Story 3                                    2010-06-17           7.7
# Harry Potter and the Deathly Hallows: Part 1   2010-11-19           7.7
# Inception                                      2010-07-16           8.3
# Shrek Forever After                            2010-05-16           6.1
# The Twilight Saga: Eclipse                     2010-06-23           6.0
# ...                                                   ...           ...
# Loving Pablo                                   2018-06-15           6.1
# The Escape                                     2015-08-14           7.0
# The Escape                                     2016-10-23           6.6
# Souvenir                                       2016-09-08           5.8
# An Actor Prepares                              2018-08-31           6.5
#
#                                               vote_count
# movie
# Toy Story 3                                       8340.0
# Harry Potter and the Deathly Hallows: Part 1     10788.0
# Inception                                        22186.0
# Shrek Forever After                               3843.0
# The Twilight Saga: Eclipse                        4909.0
# ...                                                  ...
# Loving Pablo                                       505.0
# The Escape                                           1.0
# The Escape                                          10.0
# Souvenir                                            14.0
# An Actor Prepares                                   10.0
#
# [2374 rows x 13 columns]

# %%
with zipfile.ZipFile("zippedData/im.db.zip", 'r') as imdb_zip:
    imdb_zip.extractall("zippedData")
conn = sqlite3.connect('zippedData/im.db')
cur = conn.cursor()
cur.execute("""SELECT name FROM sqlite_master WHERE type = 'table';""")

# %%
movie_basics = pd.DataFrame(
    data=cur.execute("""SELECT * FROM movie_basics;""").fetchall(),
    columns=[x[0] for x in cur.description]
)

# %%
movie_ratings = pd.DataFrame(
    data=cur.execute("""SELECT * FROM movie_ratings;""").fetchall(),
    columns=[x[0] for x in cur.description]
)

# %%
merged = pd.merge(movie_ratings, movie_basics, on='movie_id')
merged = merged.rename(columns={'primary_title':"movie"})
merged = merged.set_index('movie')
merged
# Out:
#                                                       movie_id  averagerating  \
# movie
# Laiye Je Yaarian                                    tt10356526            8.3
# Borderless                                          tt10384606            8.9
# Just Inès                                            tt1042974            6.4
# The Legend of Hercules                               tt1043726            4.2
# Até Onde?                                            tt1060240            6.5
# ...                                                        ...            ...
# Caisa                                                tt9805820            8.1
# Code Geass: Lelouch of the Rebellion - Glorific...   tt9844256            7.5
# Sisters                                              tt9851050            4.7
# The Projectionist                                    tt9886934            7.0
# Sathru                                               tt9894098            6.3
#
#                                                     numvotes  \
# movie
# Laiye Je Yaarian                                          31
# Borderless                                               559
# Just Inès                                                 20
# The Legend of Hercules                                 50352
# Até Onde?                                                 21
# ...                                                      ...
# Caisa                                                     25
# Code Geass: Lelouch of the Rebellion - Glorific...        24
# Sisters                                                   14
# The Projectionist                                          5
# Sathru                                                   128
#
#                                                                                       original_title  \
# movie
# Laiye Je Yaarian                                                                    Laiye Je Yaarian
# Borderless                                                                                Borderless
# Just Inès                                                                                  Just Inès
# The Legend of Hercules                                                        The Legend of Hercules
# Até Onde?                                                                                  Até Onde?
# ...                                                                                              ...
# Caisa                                                                                          Caisa
# Code Geass: Lelouch of the Rebellion - Glorific...  Code Geass: Lelouch of the Rebellion Episode III
# Sisters                                                                                      Sisters
# The Projectionist                                                                  The Projectionist
# Sathru                                                                                        Sathru
#
#                                                     start_year  \
# movie
# Laiye Je Yaarian                                          2019
# Borderless                                                2019
# Just Inès                                                 2010
# The Legend of Hercules                                    2014
# Até Onde?                                                 2011
# ...                                                        ...
# Caisa                                                     2018
# Code Geass: Lelouch of the Rebellion - Glorific...        2018
# Sisters                                                   2019
# The Projectionist                                         2019
# Sathru                                                    2019
#
#                                                     runtime_minutes  \
# movie
# Laiye Je Yaarian                                              117.0
# Borderless                                                     87.0
# Just Inès                                                      90.0
# The Legend of Hercules                                         99.0
# Até Onde?                                                      73.0
# ...                                                             ...
# Caisa                                                          84.0
# Code Geass: Lelouch of the Rebellion - Glorific...            120.0
# Sisters                                                         NaN
# The Projectionist                                              81.0
# Sathru                                                        129.0
#
#                                                                       genres
# movie
# Laiye Je Yaarian                                                     Romance
# Borderless                                                       Documentary
# Just Inès                                                              Drama
# The Legend of Hercules                              Action,Adventure,Fantasy
# Até Onde?                                                   Mystery,Thriller
# ...                                                                      ...
# Caisa                                                            Documentary
# Code Geass: Lelouch of the Rebellion - Glorific...   Action,Animation,Sci-Fi
# Sisters                                                         Action,Drama
# The Projectionist                                                Documentary
# Sathru                                                              Thriller
#
# [73856 rows x 7 columns]

# %%
master_df = movie_total_gross.join(merged, on = 'movie', how = 'outer', lsuffix = '__')

# %%
master_df.dropna(axis = 0, thresh = 9, inplace = True)

# %%
master_df = master_df.set_index("movie")

# %%
master_df.drop(["domestic_gross___",'movie_id','original_title', 'start_year'],  axis=1, inplace=True)

# %%
master_df["total_profit"] = (master_df.worldwide_gross - master_df.production_budget)

# %%
master_df
# Out:
#                                               studio  domestic_gross  \
# movie
# Toy Story 3                                       BV     415000000.0
# Harry Potter and the Deathly Hallows: Part 1      WB     296000000.0
# Inception                                         WB     292600000.0
# Shrek Forever After                             P/DW     238700000.0
# The Twilight Saga: Eclipse                      Sum.     300500000.0
# ...                                              ...             ...
# Souvenir                                      Strand         11400.0
# Souvenir                                      Strand         11400.0
# Beauty and the Dogs                            Osci.          8900.0
# The Quake                                      Magn.          6200.0
# An Actor Prepares                              Grav.          1700.0
#
#                                              foreign_gross    year  \
# movie
# Toy Story 3                                      652000000  2010.0
# Harry Potter and the Deathly Hallows: Part 1     664300000  2010.0
# Inception                                        535700000  2010.0
# Shrek Forever After                              513900000  2010.0
# The Twilight Saga: Eclipse                       398000000  2010.0
# ...                                                    ...     ...
# Souvenir                                               NaN  2018.0
# Souvenir                                               NaN  2018.0
# Beauty and the Dogs                                    NaN  2018.0
# The Quake                                              NaN  2018.0
# An Actor Prepares                                      NaN  2018.0
#
#                                               release_date  production_budget  \
# movie
# Toy Story 3                                   Jun 18, 2010        200000000.0
# Harry Potter and the Deathly Hallows: Part 1           NaN                NaN
# Inception                                     Jul 16, 2010        160000000.0
# Shrek Forever After                           May 21, 2010        165000000.0
# The Twilight Saga: Eclipse                    Jun 30, 2010         68000000.0
# ...                                                    ...                ...
# Souvenir                                               NaN                NaN
# Souvenir                                               NaN                NaN
# Beauty and the Dogs                                    NaN                NaN
# The Quake                                              NaN                NaN
# An Actor Prepares                                      NaN                NaN
#
#                                               worldwide_gross  averagerating  \
# movie
# Toy Story 3                                      1.068880e+09            8.3
# Harry Potter and the Deathly Hallows: Part 1              NaN            7.7
# Inception                                        8.355246e+08            8.8
# Shrek Forever After                              7.562447e+08            6.3
# The Twilight Saga: Eclipse                       7.061028e+08            5.0
# ...                                                       ...            ...
# Souvenir                                                  NaN            6.0
# Souvenir                                                  NaN            5.9
# Beauty and the Dogs                                       NaN            7.0
# The Quake                                                 NaN            6.2
# An Actor Prepares                                         NaN            5.0
#
#                                                numvotes  runtime_minutes  \
# movie
# Toy Story 3                                    682218.0            103.0
# Harry Potter and the Deathly Hallows: Part 1   425530.0            146.0
# Inception                                     1841066.0            148.0
# Shrek Forever After                            167532.0             93.0
# The Twilight Saga: Eclipse                     211733.0            124.0
# ...                                                 ...              ...
# Souvenir                                          823.0             90.0
# Souvenir                                            9.0             86.0
# Beauty and the Dogs                              1016.0            100.0
# The Quake                                        5270.0            106.0
# An Actor Prepares                                 388.0             97.0
#
#                                                                   genres  \
# movie
# Toy Story 3                                   Adventure,Animation,Comedy
# Harry Potter and the Deathly Hallows: Part 1   Adventure,Fantasy,Mystery
# Inception                                        Action,Adventure,Sci-Fi
# Shrek Forever After                           Adventure,Animation,Comedy
# The Twilight Saga: Eclipse                       Adventure,Drama,Fantasy
# ...                                                                  ...
# Souvenir                                             Drama,Music,Romance
# Souvenir                                                  Comedy,Romance
# Beauty and the Dogs                                 Crime,Drama,Thriller
# The Quake                                          Action,Drama,Thriller
# An Actor Prepares                                                 Comedy
#
#                                               total_profit
# movie
# Toy Story 3                                    868879522.0
# Harry Potter and the Deathly Hallows: Part 1           NaN
# Inception                                      675524642.0
# Shrek Forever After                            591244673.0
# The Twilight Saga: Eclipse                     638102828.0
# ...                                                    ...
# Souvenir                                               NaN
# Souvenir                                               NaN
# Beauty and the Dogs                                    NaN
# The Quake                                              NaN
# An Actor Prepares                                      NaN
#
# [3122 rows x 12 columns]

# %%
# runtime bins
binned_df = master_df.copy()
bins = [90, 150, 210, 270] # bins of under 1.5 hours, 1.5-2.5 hours, 2.5-3.5 hours, 3.5+ hours
runtime_bins = []
for index, row in binned_df.iterrows():
    runtime = row['runtime_minutes']
    if runtime < bins[0]:
        runtime_bins.append(0)
    elif runtime < bins[1]:
        runtime_bins.append(1)
    elif runtime < bins[2]:
        runtime_bins.append(2)
    else:
        runtime_bins.append(3)
binned_df['runtime_bins'] = runtime_bins
binned_df[binned_df['runtime_bins'] == 0]
# Out:
#                     studio  domestic_gross foreign_gross    year  \
# movie
# Gulliver's Travels     Fox      42800000.0     194600000  2010.0
# Yogi Bear               WB     100200000.0     101300000  2010.0
# Unstoppable            Fox      81600000.0      86200000  2010.0
# Unstoppable            Fox      81600000.0      86200000  2010.0
# Date Night             Fox      98700000.0      53600000  2010.0
# ...                    ...             ...           ...     ...
# In Between              FM        108000.0           NaN  2018.0
# Just a Breath Away    EOne         78000.0           NaN  2018.0
# Under the Tree       Magn.         67600.0           NaN  2018.0
# The Workshop        Strand         22100.0           NaN  2018.0
# Souvenir            Strand         11400.0           NaN  2018.0
#
#                     release_date  production_budget  worldwide_gross  \
# movie
# Gulliver's Travels  Dec 25, 2010        112000000.0      232017848.0
# Yogi Bear           Dec 17, 2010         80000000.0      204774690.0
# Unstoppable         Nov 12, 2010         95000000.0      165720921.0
# Unstoppable         Nov 12, 2010         95000000.0      165720921.0
# Date Night           Apr 9, 2010         55000000.0      152269033.0
# ...                          ...                ...              ...
# In Between                   NaN                NaN              NaN
# Just a Breath Away           NaN                NaN              NaN
# Under the Tree               NaN                NaN              NaN
# The Workshop                 NaN                NaN              NaN
# Souvenir                     NaN                NaN              NaN
#
#                     averagerating  numvotes  runtime_minutes  \
# movie
# Gulliver's Travels            4.9   61178.0             85.0
# Yogi Bear                     4.6   18934.0             80.0
# Unstoppable                   4.3     551.0             65.0
# Unstoppable                   8.1       8.0             84.0
# Date Night                    6.3  144683.0             88.0
# ...                           ...       ...              ...
# In Between                    7.2       5.0             45.0
# Just a Breath Away            5.9    3501.0             89.0
# Under the Tree                6.9    2486.0             89.0
# The Workshop                  8.0       5.0             77.0
# Souvenir                      5.9       9.0             86.0
#
#                                         genres  total_profit  runtime_bins
# movie
# Gulliver's Travels     Adventure,Comedy,Family   120017848.0             0
# Yogi Bear           Adventure,Animation,Comedy   124774690.0             0
# Unstoppable                        Documentary    70720921.0             0
# Unstoppable                        Documentary    70720921.0             0
# Date Night                Comedy,Crime,Romance    97269033.0             0
# ...                                        ...           ...           ...
# In Between           Documentary,Drama,Romance           NaN             0
# Just a Breath Away                      Sci-Fi           NaN             0
# Under the Tree            Comedy,Drama,Mystery           NaN             0
# The Workshop                Documentary,Family           NaN             0
# Souvenir                        Comedy,Romance           NaN             0
#
# [435 rows x 13 columns]

# %%
binned_df['runtime_bins'].value_counts()
# Out:
# 1    2460
# 0     435
# 3     123
# 2     104
# Name: runtime_bins, dtype: int64

# %%
master_df["Profit%"] = ((master_df.total_profit)/master_df.production_budget)*100
binned_df["Profit%"] = ((binned_df.total_profit)/binned_df.production_budget)*100

# %% [markdown]
# ## Visualizations Used in Presentation

# %%
fix, ax = plt.subplots()
sns.set(rc={"figure.figsize":(10, 7)})
sns.set_theme(style="whitegrid", font_scale=1.5)
runtime_df = binned_df[binned_df['runtime_bins'] != 0]
plot = sns.barplot(data = binned_df, x = 'runtime_bins', y = 'averagerating', color = 'green').set(title = 'Average Rating vs. Runtime')
ax.set_xticklabels(["below 1.5","1.5 - 2.5","2.5 - 3.5","above 3.5"])
ax.axhline(y = binned_df['averagerating'].mean(), color='r', linestyle='dotted', label = "Mean of Average Rating")
ax.legend()
ax.set_xlabel("Runtime (Hours)")
ax.set_ylabel("Average Rating")
plt.show()

# %%
import matplotlib.ticker as ticker
fix, ax = plt.subplots()
sns.set(rc={"figure.figsize":(10, 7)})
sns.set_theme(style="whitegrid", font_scale=1.5)
plot = sns.barplot(data = binned_df, x = 'runtime_bins', y = 'Profit%', color = 'green').set(title = 'Average Profit Percentage vs. Runtime')
ax.set_xticklabels(["below 1.5","1.5 - 2.5","2.5 - 3.5","above 3.5"])
ax.set_xlabel("Runtime (Hours)")
ax.set_ylabel("Average Profit Percentage")
ax.axhline(y = binned_df['Profit%'].mean(), color='r', linestyle='dotted', label = "Mean of Average Profit Percentage")
ax.legend()
plt.show()

# %% [markdown]
# ## Additional Visualizations

# %%
binned_df['rating_bins'] = np.trunc((binned_df['averagerating']/1))
binned_df.head()
# Out:
#                                              studio  domestic_gross  \
# movie
# Toy Story 3                                      BV     415000000.0
# Harry Potter and the Deathly Hallows: Part 1     WB     296000000.0
# Inception                                        WB     292600000.0
# Shrek Forever After                            P/DW     238700000.0
# The Twilight Saga: Eclipse                     Sum.     300500000.0
#
#                                              foreign_gross    year  \
# movie
# Toy Story 3                                      652000000  2010.0
# Harry Potter and the Deathly Hallows: Part 1     664300000  2010.0
# Inception                                        535700000  2010.0
# Shrek Forever After                              513900000  2010.0
# The Twilight Saga: Eclipse                       398000000  2010.0
#
#                                               release_date  production_budget  \
# movie
# Toy Story 3                                   Jun 18, 2010        200000000.0
# Harry Potter and the Deathly Hallows: Part 1           NaN                NaN
# Inception                                     Jul 16, 2010        160000000.0
# Shrek Forever After                           May 21, 2010        165000000.0
# The Twilight Saga: Eclipse                    Jun 30, 2010         68000000.0
#
#                                               worldwide_gross  averagerating  \
# movie
# Toy Story 3                                      1.068880e+09            8.3
# Harry Potter and the Deathly Hallows: Part 1              NaN            7.7
# Inception                                        8.355246e+08            8.8
# Shrek Forever After                              7.562447e+08            6.3
# The Twilight Saga: Eclipse                       7.061028e+08            5.0
#
#                                                numvotes  runtime_minutes  \
# movie
# Toy Story 3                                    682218.0            103.0
# Harry Potter and the Deathly Hallows: Part 1   425530.0            146.0
# Inception                                     1841066.0            148.0
# Shrek Forever After                            167532.0             93.0
# The Twilight Saga: Eclipse                     211733.0            124.0
#
#                                                                   genres  \
# movie
# Toy Story 3                                   Adventure,Animation,Comedy
# Harry Potter and the Deathly Hallows: Part 1   Adventure,Fantasy,Mystery
# Inception                                        Action,Adventure,Sci-Fi
# Shrek Forever After                           Adventure,Animation,Comedy
# The Twilight Saga: Eclipse                       Adventure,Drama,Fantasy
#
#                                               total_profit  runtime_bins  \
# movie
# Toy Story 3                                    868879522.0             1
# Harry Potter and the Deathly Hallows: Part 1           NaN             1
# Inception                                      675524642.0             1
# Shrek Forever After                            591244673.0             1
# The Twilight Saga: Eclipse                     638102828.0             1
#
#                                                  Profit%  rating_bins
# movie
# Toy Story 3                                   434.439761          8.0
# Harry Potter and the Deathly Hallows: Part 1         NaN          7.0
# Inception                                     422.202901          8.0
# Shrek Forever After                           358.330105          6.0
# The Twilight Saga: Eclipse                    938.386512          5.0

# %%
# budget ranges for short vs long runtime
print("Short movies (0-1.5 hours)")
print("Mean: " + str(binned_df[binned_df['runtime_bins'] == 0]['total_profit'].mean())) # 79 million (shorter movies)
print("Min: " + str(binned_df[binned_df['runtime_bins'] == 0]['total_profit'].min()))
print("Max: " + str(binned_df[binned_df['runtime_bins'] == 0]['total_profit'].max()))

print("\nLong movies (2.5-3.5 hours)")
print("Mean: " + str(binned_df[binned_df['runtime_bins'] == 2]['total_profit'].mean())) # 190 million (longer movies)
print("Min: " + str(binned_df[binned_df['runtime_bins'] == 2]['total_profit'].min()))
print("Max: " + str(binned_df[binned_df['runtime_bins'] == 2]['total_profit'].max()))
# Out:
# Short movies (0-1.5 hours)
# Mean: 78910779.24598931
# Min: -110450242.0
# Max: 959727750.0
#
# Long movies (2.5-3.5 hours)
# Mean: 190649420.41860464
# Min: -19722057.0
# Max: 928790543.0

# %%
sns.set(rc={"figure.figsize":(25, 10)})
new_df = master_df.dropna(axis=0, subset=['runtime_minutes'])
new_df_top_5 = new_df.sort_values(['averagerating'], ascending = False).head(5)
new_df_top_5
sns.barplot(data = new_df_top_5, x = 'runtime_minutes', y = 'averagerating').set(title = 'Runtime in Minutes by Average Rating')
#the higher ratings have a runtime range of 68-115 minutes (1 - 2 hrs)
# Out:
# [Text(0.5, 1.0, 'Runtime in Minutes by Average Rating')]

# %%
# runtime bins
bins = [30, 90, 150, 210, 270] # bins of 0-0.5 hours, 0.5-1.5 hours, 1.5-2.5 hours, 2.5-3.5 hours, 3.5+ hours
for index, row in master_df.iterrows():
    runtime = row['runtime_minutes']
    if runtime < bins[0]:
        master_df.at[index,'runtime_bins'] = 0
    elif runtime < bins[1]:
        master_df.at[index,'runtime_bins'] = 1
    elif runtime < bins[2]:
        master_df.at[index,'runtime_bins'] = 2
    elif runtime < bins[3]:
        master_df.at[index,'runtime_bins'] = 3
    else:
        master_df.at[index,'runtime_bins'] = 4
master_df.head()
# Out:
#                                              studio  domestic_gross  \
# movie
# Toy Story 3                                      BV     415000000.0
# Harry Potter and the Deathly Hallows: Part 1     WB     296000000.0
# Inception                                        WB     292600000.0
# Shrek Forever After                            P/DW     238700000.0
# The Twilight Saga: Eclipse                     Sum.     300500000.0
#
#                                              foreign_gross    year  \
# movie
# Toy Story 3                                      652000000  2010.0
# Harry Potter and the Deathly Hallows: Part 1     664300000  2010.0
# Inception                                        535700000  2010.0
# Shrek Forever After                              513900000  2010.0
# The Twilight Saga: Eclipse                       398000000  2010.0
#
#                                               release_date  production_budget  \
# movie
# Toy Story 3                                   Jun 18, 2010        200000000.0
# Harry Potter and the Deathly Hallows: Part 1           NaN                NaN
# Inception                                     Jul 16, 2010        160000000.0
# Shrek Forever After                           May 21, 2010        165000000.0
# The Twilight Saga: Eclipse                    Jun 30, 2010         68000000.0
#
#                                               worldwide_gross  averagerating  \
# movie
# Toy Story 3                                      1.068880e+09            8.3
# Harry Potter and the Deathly Hallows: Part 1              NaN            7.7
# Inception                                        8.355246e+08            8.8
# Shrek Forever After                              7.562447e+08            6.3
# The Twilight Saga: Eclipse                       7.061028e+08            5.0
#
#                                                numvotes  runtime_minutes  \
# movie
# Toy Story 3                                    682218.0            103.0
# Harry Potter and the Deathly Hallows: Part 1   425530.0            146.0
# Inception                                     1841066.0            148.0
# Shrek Forever After                            167532.0             93.0
# The Twilight Saga: Eclipse                     211733.0            124.0
#
#                                                                   genres  \
# movie
# Toy Story 3                                   Adventure,Animation,Comedy
# Harry Potter and the Deathly Hallows: Part 1   Adventure,Fantasy,Mystery
# Inception                                        Action,Adventure,Sci-Fi
# Shrek Forever After                           Adventure,Animation,Comedy
# The Twilight Saga: Eclipse                       Adventure,Drama,Fantasy
#
#                                               total_profit     Profit%  \
# movie
# Toy Story 3                                    868879522.0  434.439761
# Harry Potter and the Deathly Hallows: Part 1           NaN         NaN
# Inception                                      675524642.0  422.202901
# Shrek Forever After                            591244673.0  358.330105
# The Twilight Saga: Eclipse                     638102828.0  938.386512
#
#                                               runtime_bins
# movie
# Toy Story 3                                            2.0
# Harry Potter and the Deathly Hallows: Part 1           2.0
# Inception                                              2.0
# Shrek Forever After                                    2.0
# The Twilight Saga: Eclipse                             2.0

# %%
master_df['rating_bins'] = np.trunc((master_df['averagerating']/1))
master_df.head()
# Out:
#                                              studio  domestic_gross  \
# movie
# Toy Story 3                                      BV     415000000.0
# Harry Potter and the Deathly Hallows: Part 1     WB     296000000.0
# Inception                                        WB     292600000.0
# Shrek Forever After                            P/DW     238700000.0
# The Twilight Saga: Eclipse                     Sum.     300500000.0
#
#                                              foreign_gross    year  \
# movie
# Toy Story 3                                      652000000  2010.0
# Harry Potter and the Deathly Hallows: Part 1     664300000  2010.0
# Inception                                        535700000  2010.0
# Shrek Forever After                              513900000  2010.0
# The Twilight Saga: Eclipse                       398000000  2010.0
#
#                                               release_date  production_budget  \
# movie
# Toy Story 3                                   Jun 18, 2010        200000000.0
# Harry Potter and the Deathly Hallows: Part 1           NaN                NaN
# Inception                                     Jul 16, 2010        160000000.0
# Shrek Forever After                           May 21, 2010        165000000.0
# The Twilight Saga: Eclipse                    Jun 30, 2010         68000000.0
#
#                                               worldwide_gross  averagerating  \
# movie
# Toy Story 3                                      1.068880e+09            8.3
# Harry Potter and the Deathly Hallows: Part 1              NaN            7.7
# Inception                                        8.355246e+08            8.8
# Shrek Forever After                              7.562447e+08            6.3
# The Twilight Saga: Eclipse                       7.061028e+08            5.0
#
#                                                numvotes  runtime_minutes  \
# movie
# Toy Story 3                                    682218.0            103.0
# Harry Potter and the Deathly Hallows: Part 1   425530.0            146.0
# Inception                                     1841066.0            148.0
# Shrek Forever After                            167532.0             93.0
# The Twilight Saga: Eclipse                     211733.0            124.0
#
#                                                                   genres  \
# movie
# Toy Story 3                                   Adventure,Animation,Comedy
# Harry Potter and the Deathly Hallows: Part 1   Adventure,Fantasy,Mystery
# Inception                                        Action,Adventure,Sci-Fi
# Shrek Forever After                           Adventure,Animation,Comedy
# The Twilight Saga: Eclipse                       Adventure,Drama,Fantasy
#
#                                               total_profit     Profit%  \
# movie
# Toy Story 3                                    868879522.0  434.439761
# Harry Potter and the Deathly Hallows: Part 1           NaN         NaN
# Inception                                      675524642.0  422.202901
# Shrek Forever After                            591244673.0  358.330105
# The Twilight Saga: Eclipse                     638102828.0  938.386512
#
#                                               runtime_bins  rating_bins
# movie
# Toy Story 3                                            2.0          8.0
# Harry Potter and the Deathly Hallows: Part 1           2.0          7.0
# Inception                                              2.0          8.0
# Shrek Forever After                                    2.0          6.0
# The Twilight Saga: Eclipse                             2.0          5.0

# %%
sns.set(rc={"figure.figsize":(10, 7)})
sns.barplot(data = master_df, x = 'rating_bins', y = 'runtime_minutes', palette = 'pastel').set(title = 'Runtime in Minutes by Average Rating Bins')
#runtime in bin 7: ~110 min
#runtime in bin 8: ~115 min
#runtime in bin 9: ~95 min
#movies with lower runtime in minutes have higher ratings
# Out:
# [Text(0.5, 1.0, 'Runtime in Minutes by Average Rating Bins')]

# %%
sns.set(rc={"figure.figsize":(10, 7)})
group_means=master_df.groupby(['studio'])['averagerating'].mean().sort_values(ascending=False)
top_20_studios = group_means.head(10)

sns.barplot(x = top_20_studios.index, y = top_20_studios)
# Out:
# <AxesSubplot:xlabel='studio', ylabel='averagerating'>

# %%
sns.scatterplot(x="averagerating",
y="numvotes",
data=master_df);
# higher ratings are usually more credible

# %%
sns.scatterplot(x="averagerating",
y="production_budget",
data=master_df);

# %%
sns.set(rc={"figure.figsize":(25, 10)})
new_df = master_df.dropna(axis=0, subset=['production_budget'])
new_df_top = new_df.sort_values(['production_budget'])
sns.barplot(data = new_df_top, x = 'production_budget', y = 'averagerating').set(title = 'Ratings per production budget')
# Out:
# [Text(0.5, 1.0, 'Ratings per production budget')]
